# %%
from qiskit import *
from qiskit.compiler import transpile
from qiskit.visualization import plot_histogram
from qiskit.tools.monitor import job_monitor
IBMQ.load_accounts()
# %matplotlib inline

# %%
qr = QuantumRegister(6, 'qr')
cr = ClassicalRegister(6, 'cr')
ghz = QuantumCircuit(qr, cr, name='ghz')

ghz.h(qr[0])
ghz.cx(qr[0], qr[1])
ghz.cx(qr[0], qr[2])
ghz.cx(qr[0], qr[3])
ghz.cx(qr[0], qr[4])
ghz.cx(qr[0], qr[5])
ghz.barrier(qr)
ghz.measure(qr, cr)
ghz.draw(output='latex')
# Out:
# <PIL.Image.Image image mode=RGB size=938x948 at 0x128E30400>

# %%
device = IBMQ.get_backend('ibmq_16_melbourne')

# %%
trans_ghz = transpile(ghz, device)

# %%
trans_ghz.draw(output='mpl')
